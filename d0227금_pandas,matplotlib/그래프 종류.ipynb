# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] =  15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize=(10,6), dpi = 50)
labels = ['홍길동','김길동','이길동']
values = [80, 60,90]
colors = ['r','b','g']

plt.bar(labels, values, color = colors)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.figure(figsize=(10,6), dpi = 40)
plt.bar(labels, values, color = colors, alpha=0.5)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.figure(figsize=(10,6), dpi = 40)
plt.bar(labels, values, color = colors)
plt.ylim(40, 100)
# Out:
# (40.0, 100.0)

# %%
plt.figure(figsize=(10,6), dpi = 40)
plt.bar(labels, values, width=0.3)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.figure(figsize=(10,6), dpi = 40)
plt.bar(labels, values, width=0.3)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.figure(figsize=(10,6), dpi = 40)
plt.bar(labels, values, width=0.3)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2], [Text(0, 0, '홍길동'), Text(1, 0, '김길동'), Text(2, 0, '이길동')])

# %%
plt.figure(figsize=(10,6), dpi = 40)
plt.barh(labels, values)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.figure(figsize=(10,6), dpi = 40)
plt.barh(labels, values)
plt.xlim(50,95)
# Out:
# (50.0, 95.0)

# %%
plt.figure(figsize=(10,6), dpi = 50)
bar = plt.bar(labels, values)
bar[0].set_hatch('/')
bar[1].set_hatch('x')
bar[2].set_hatch('..')

# %%
import pandas as pd

# %%
df = pd.read_excel('score.xlsx')
df
# Out:
#    번호   이름  주소  나이   점수      언어
# 0  1번  김길동  광주  33   76  Python
# 1  2번  이길동  서울  23   88    Java
# 2  3번  강길동  대구  30   98     C++
# 3  4번  홍길동  대전  20  100     NaN
# 4  5번  박길동  광주  21   60     NaN
# 5  6번  나길동  서울  25   90       C

# %%
plt.figure(figsize=(12,5), dpi=50)
plt.plot(df['이름'], df['점수'])
plt.show()

# %%
plt.figure(figsize=(12,5), dpi=50)
plt.plot(df['이름'], df['점수'])
plt.plot(df['이름'], df['나이'])
plt.show()

# %%
plt.figure(figsize=(12,5), dpi=50)
plt.plot(df['이름'], df['점수'])
plt.plot(df['이름'], df['나이'])
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(12,5), dpi=50)
plt.plot(df['이름'], df['점수'])
plt.plot(df['이름'], df['나이'])
plt.grid(axis='x')
plt.show()

# %%
plt.figure(figsize=(12,5), dpi=50)
plt.plot(df['이름'], df['점수'])
plt.plot(df['이름'], df['나이'])
plt.grid(axis='y', color='r', alpha=0.5, linestyle='--', linewidth=2)
plt.show()
