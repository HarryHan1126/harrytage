# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=2 in c:\users\user\anaconda3\lib\site-packages (from opencv-python) (2.3.5)
# Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    --------------------- ------------------ 21.5/40.2 MB 112.9 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.2 MB 111.0 MB/s eta 0:00:01
#    ---------------------------------------- 40.2/40.2 MB 98.4 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.13.0.92

# %%
import numpy as np
import cv2 #색깔 순서가 bgr 로 감, 좌표체계도 다름

# %%
image = cv2.imread('sample.jpg')
cv2.imshow('Original', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gray_color = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('Gray', gray_color)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
edges = cv2.Canny(gray_color, 50, 150)
cv2.imshow('edges', edges)
cv2.waitKey(0)
cv2.destroyAllWindows()
