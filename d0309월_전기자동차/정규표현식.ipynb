# %%
import re
p = re.compile('ab*')
type(p)
# Out:
# re.Pattern

# %%
p = re.compile('[a-z]+')

# %%
m = p.match("python")
print(m)
# Out:
# <re.Match object; span=(0, 6), match='python'>

# %%
m = p.match("3 python")
print(m)
# Out:
# None

# %%
m = p.match("pyt3hon")
print(m)
# Out:
# <re.Match object; span=(0, 3), match='pyt'>
